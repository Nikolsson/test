# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ilya**
# engineer

# %% [markdown]
# *I'm interested in medical application of DS*

# %% [markdown]
# ### Just some math

# %%
x=1.0
y=2.5
print(x+y)
# Out:
# 3.5

# %% [markdown]
# Some text
# ![smiley.jpg](attachment:smiley.jpg)
